# %%
import pandas as pd
import plotly.express as px
import plotly.io as pio
pio.renderers.default = 'browser'

# %%
df = pd.read_csv(r"C:\Users\cauai\Desktop\repos\repo\aya-case\aya-case\data\raw\dados_cdp.csv")

# %%
df
# Out:
#                                usuario_id  idade    genero  \
# 0    dcdff191-8e4f-4672-aa21-61ddd6e16b65     56  Feminino
# 1    5d5dfeaa-bb0c-4766-ad94-7135abe976f8     46  Feminino
# 2    f081b639-9f96-415a-b139-a37336b25350     32     Outro
# 3    0ea9d453-5d0a-409c-ae9d-a5804bcabb76     45     Outro
# 4    a1da2ac0-2c8c-459e-88a7-99207549a541     39  Feminino
# ..                                    ...    ...       ...
# 995  05fcc3e4-cad8-415a-8f82-1c98646c427e     29     Outro
# 996  19458e79-8bcb-4e20-af2f-cbc498a727a6     34  Feminino
# 997  c0cec131-671b-4799-8277-1bb3ea1c45a5     42  Feminino
# 998  ecebb6f8-34f9-42c4-9f8b-42633f0608ab     19  Feminino
# 999  cad4ffdc-2293-414e-b961-2c323de39d0c     27     Outro
#
#                                   interesse  dias_desde_cadastro  \
# 0        ['Viagens', 'Viagens', 'Notícias']                   20
# 1      ['Tecnologia', 'Leitura', 'Viagens']                   71
# ...

# %%
df.describe()
# Out:
#              idade  dias_desde_cadastro  dias_engajamento  \
# count  1000.000000          1000.000000       1000.000000
# mean     39.157000            26.673000         17.755000
# std      12.653397            25.864668          7.297001
# min      18.000000           -17.000000          5.000000
# 25%      28.000000             4.000000         12.000000
# 50%      39.000000            26.000000         18.000000
# 75%      50.000000            49.000000         24.000000
# max      60.000000            72.000000         30.000000
#
#        engajamento_dias_leitura
# count               1000.000000
# mean                   8.855000
# std                    6.731068
# min                    0.000000
# 25%                    4.000000
# 50%                    7.000000
# 75%                   13.000000
# max                   29.000000

# %%
df.isnull().sum()
# Out:
# usuario_id                  0
# idade                       0
# genero                      0
# interesse                   0
# dias_desde_cadastro         0
# dias_engajamento            0
# boas_vindas_data            0
# boas_vindas_eventos         0
# engajamento_inicio          0
# engajamento_fim             0
# engajamento_dias_leitura    0
# retencao_status             0
# dtype: int64

# %%
df[df['dias_desde_cadastro'] < 0]
# Out:
#                                usuario_id  idade     genero  \
# 5    e6a81de5-5a94-429c-956c-b690e034bc8d     32      Outro
# 12   aeb8446f-1ebc-47fe-a050-b5796365f4a5     21      Outro
# 16   a08c7975-82cf-4fae-b44b-3f4a7b905105     19   Feminino
# 23   7221f71c-edbd-4365-8eb4-2d8eaf08bdcb     43      Outro
# 25   7b6e6c8c-f6bc-4599-9a5f-ccf50e1c277c     30  Masculino
# ..                                    ...    ...        ...
# 971  a907415f-94c9-4c91-80b2-489759866661     22   Feminino
# 975  4fc11176-8a32-407f-a1e9-75dce4c9f0b2     20  Masculino
# 981  1e5a574f-8044-44bf-8a2f-47cc371281f1     57   Feminino
# 994  00acae25-1a99-41ed-8def-326cc6c76306     30      Outro
# 998  ecebb6f8-34f9-42c4-9f8b-42633f0608ab     19   Feminino
#
#                                interesse  dias_desde_cadastro  \
# 5               ['Notícias', 'Esportes']                   -8
# 12                            ['Filmes']                   -3
# ...

# %%
df['boas_vindas_eventos'].unique()
# Out:
# array(["['cadastro_concluido', 'primeiro_acesso']",
#        "['cadastro_concluido', 'primeiro_acesso', 'tutorial_completo']"],
#       dtype=object)
